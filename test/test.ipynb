# %%
import math 
math.fabs(-3)
# Out:
# 3.0

# %%
# Out:
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (3.9 MB/7.0 MB, attempt 1)
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.62.1-cp313-cp313-win_amd64.whl.metadata (119 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached numpy-2.4.3-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached pillow-12.1.1-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt

# example data
transmission = [1, 2, 3, 4, 5]
sales = [10, 20, 30, 40, 50]

plt.scatter(transmission, sales)

# labels
plt.xlabel('Transmission')
plt.ylabel('Sales')
plt.title("t vs s")
# show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 # example data
#       4 transmission = [1, 2, 3, 4, 5]
#
# ModuleNotFoundError: No module named 'matplotlib'
